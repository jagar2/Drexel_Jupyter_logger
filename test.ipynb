# %%
import drexel_jupyter_logger

drexel_jupyter_logger.decode_log_file('./output.log', "7mPZKa3gJZn4ng0WJ5TsUmuQC2RK9XBAwTzrTEjbyB0=" )
# Out:
# ['info, hostname, jupyter-tt672, 2024-02-05 13:18:47.',
#  'info, IPAddr, 10.244.201.215, 2024-02-05 13:18:47.',
#  'info, assignment, Midterm_2024, 2024-02-05 13:18:47.',
#  'info, first_name, Tom, 2024-02-05 13:18:47.',
#  'info, last_name, Thuong, 2024-02-05 13:18:47.',
#  'info, drexel_id, tt672, 2024-02-05 13:18:47.',
#  'info, drexel_email, tt672@drexel.edu, 2024-02-05 13:18:47.',
#  "code run: from ENGR131_Util_2024 import StudentInfoForm\nfrom ENGR131_Util_2024 import responses\nfrom ENGR131_Util_2024 import engr131_midterm\n\n# Register the log function to be called before any cell is executed\nget_ipython().events.register('pre_run_cell', engr131_midterm)\n\nStudentInfoForm(**responses)",
#  'code run: from ENGR131_Util_2024 import DataTypes\nfrom ENGR131_Util_2024 import responses\n\nself = DataTypes(**responses)\n',
#  'code run: from ENGR131_Util_2024 import DataTypes\nfrom ENGR131_Util_2024 import responses\n\nself = DataTypes(**responses)\n',
# ...
